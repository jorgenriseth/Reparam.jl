# %%
using Plots

# %%
include("../src/plotters.jl")
include("../src/transform.jl")
# Out:
# Q_transform (generic function with 2 methods)

# %%
θ = π / 8
s0 = 3.
r(t) = 0.5 +  t
s(t) = (r(t)^3 + (s0^3-1) * r(0)^3)^(1/3) / r(t)
ρ(t) = s(t) * r(t)

c(t) = [r(t) * cos(θ), r(t) * sin(θ)]
a(t) = [ρ(t) * cos(θ), ρ(t) * sin(θ)]

Xcoarse = 0:0.1:1
p1 = plot_curve(c, 10, shape=:circle)
plot_curve!(a, 10, shape=:x, markersize=7)

qc = Q_transform(c)
qa = Q_transform(a)

p2 = plot_curve(qc, 10, shape=:circle, markersize=5)
plot_curve!(qa, 10, shape=:x, markersize=7)

plot(p1, p2, size=(800, 200))
